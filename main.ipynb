# %%
import torch
print("Torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else None)
# Out:
# Torch: 2.5.1+cu121
# CUDA available: True
# GPU: NVIDIA GeForce RTX 3060

# %%
from inference.predict import predict
import cv2
from matplotlib import pyplot as plt

image_path = r'C:\Users\PC\Documents\college\CV\Cs406\lab5\data\images\maksssksksss10.png'  
pred_box = predict(image_path)
print(pred_box)
# Out:
# image 1/1 C:\Users\PC\Documents\college\CV\Cs406\lab5\data\images\maksssksksss10.png: 640x512 1 with_mask, 74.2ms
# Speed: 4.0ms preprocess, 74.2ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 512)
# Results saved to C:\Users\PC\Documents\college\CV\Cs406\lab5\runs\detect\predict6
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 11
#       8 img = cv2.imread(image_path)
#       9 img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# ---> 11 for b in pred_box:
#      12     x1, y1, x2, y2, conf, cls = b
#      13     label = f"{int(cls)}:{conf:.2f}"
#
# TypeError: 'NoneType' object is not iterable
